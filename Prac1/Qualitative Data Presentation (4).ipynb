# %% [markdown]
# # Data Presentation of Qualitative Data

# %%
import pandas as pd                         #stores data like excel in data form
import seaborn as sns                       #for making graphs
import matplotlib.pyplot as plt             #for plotting in graph
# %matplotlib inline

# %%
df = pd.DataFrame({
    'Flavor': ['Chocolate', 'Vanilla', 'Mint', 'Swirl', 'Nut'],
    'Orders': [1500,  670,  950,  450,   75]
})
df.plot(kind='bar', x='Flavor', y='Orders', legend=None, title='Ice Cream Sales')
plt.show()

# %%
df.plot(kind='pie', labels=df['Flavor'], y='Orders', legend=None, autopct='%.2f%%', title='Ice Cream Sales')
plt.tight_layout()
plt.show()

# %%
def pareto_plot(df, x=None, y=None, title=None, show_pct_y=False, pct_format='{0:.0%}'):
    xlabel = x
    ylabel = y
    tmp = df.sort_values(y, ascending=False)
    x = tmp[x].values
    y = tmp[y].values
    weights = y / y.sum()
    cumsum = weights.cumsum()
    
    fig, ax1 = plt.subplots()       #ax1 returns axis
    ax1.bar(x, y)
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)

    ax2 = ax1.twinx()               #twinx creates twin axis ax2
    ax2.plot(x, cumsum, '-ro', alpha=0.5)
    ax2.set_ylabel('', color='r')
    ax2.tick_params('y', colors='r')
    
    vals = ax2.get_yticks()
    ax2.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

    # hide y-labels on right side
    if not show_pct_y:
        ax2.set_yticks([])
    
    formatted_weights = [pct_format.format(x) for x in cumsum]
    for i, txt in enumerate(formatted_weights):
        ax2.annotate(txt, (x[i], cumsum[i]), fontweight='heavy')    
    
    if title:
        plt.title(title)
    
    plt.tight_layout()
    plt.show()

# %%
pareto_plot(df, x='Flavor', y='Orders', title='Ice Cream Sales')
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_3344\3937679125.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
df = pd.DataFrame([[10, 20, 30, 40], [7, 14, 21, 28], [15, 15, 8, 12],                  #dictionary mein upar se neeche columns first
                   [15, 14, 1, 8], [7, 1, 1, 8], [5, 4, 9, 2]],
                  columns=['Apple', 'Orange', 'Banana', 'Pear'],
                  index=['Basket1', 'Basket2', 'Basket3', 'Basket4',
                         'Basket5', 'Basket6'])
 
box = plt.boxplot(df, patch_artist=True)
 
colors = ['blue', 'green', 'purple', 'tan', 'pink', 'red']
 
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
 
plt.show()

# %%
df
# Out:
#          Apple  Orange  Banana  Pear
# Basket1     10      20      30    40
# Basket2      7      14      21    28
# Basket3     15      15       8    12
# Basket4     15      14       1     8
# Basket5      7       1       1     8
# Basket6      5       4       9     2

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
x = [[1.2, 2.3, 3.0, 4.5],
     [1.1, 2.2, 2.9, 5.0]]
 
df = pd.DataFrame(x, index=['Apple', 'Orange'])
df.T.boxplot()                                         #boxplot is transposed
 
plt.subplots_adjust(bottom=0.25)
 
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
 
x = [[1.2, 2.3, 3.0, 4.5],
     [1.1, 2.2, 2.9, 5.0]]
 
df = pd.DataFrame(x, index=['Apple', 'Orange'])
print(df)
 
df.T.boxplot(vert=False)
plt.subplots_adjust(left=0.25)
 
plt.show()
# Out:
#           0    1    2    3
# Apple   1.2  2.3  3.0  4.5
# Orange  1.1  2.2  2.9  5.0
