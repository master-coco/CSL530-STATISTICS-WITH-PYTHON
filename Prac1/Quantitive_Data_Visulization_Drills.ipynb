# %% [markdown]
# #### Drill on Data Visulization

# %% [markdown]
# ##### 1. Import librarires

# %%
import seaborn as sns               #for data visualization 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### 2. Import "geyser" dataset using sns libraries

# %%
data1= sns.load_dataset("geyser")

# %% [markdown]
# ##### 3. Visulaize Data in Tabular Format

# %%
print(data1)
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %% [markdown]
# ##### 4. Display the descriptive statistics measures

# %%
data1.describe()
# Out:
#          duration     waiting
# count  272.000000  272.000000
# mean     3.487783   70.897059
# std      1.141371   13.594974
# min      1.600000   43.000000
# 25%      2.162750   58.000000
# 50%      4.000000   76.000000
# 75%      4.454250   82.000000
# max      5.100000   96.000000

# %% [markdown]
# ##### 5. Create Histogram for "Duration" fileds in datasets

# %%
sns.histplot(data1['duration'], bins=20).set(title="Histogram of Duration in Geyser Dataset")
# Out:
# [Text(0.5, 1.0, 'Histogram of Duration in Geyser Dataset')]

# %% [markdown]
# ##### 6. Create Histogram for "waiting" fileds in datasets

# %%
sns.histplot(data1['waiting'], bins=20).set(title="Histogram of Wating of Geyser Dataset")
# Out:
# [Text(0.5, 1.0, 'Histogram of Wating of Geyser Dataset')]

# %% [markdown]
# ##### 7. Show the distribution of data along with Histogram
# * Duration
# * Waiting

# %%
sns.histplot(data=data1,x='waiting')
# Out:
# <Axes: xlabel='waiting', ylabel='Count'>

# %% [markdown]
# ##### 8. Plot a histogram of both the total bill and the tips'

# %%
data2=sns.load_dataset("tips")
plt.subplot(1,2,1)  
sns.histplot(data2['total_bill'],bins=15)
plt.subplot(1,2,2,sp)
sns.histplot(data2['tip'], bins=15)
plt.show()

# %% [markdown]
# ##### 9. Create boxplot

# %%
sns.boxplot(data2['total_bill'],orient='h')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### 10. Creating Histograms and Boxplots Plotted by Groups
# Note: Use Kind  kind  attribute to make groups

# %%
data2.groupby("sex")
sns.boxplot(data=data2, x='day', y='tip')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>
