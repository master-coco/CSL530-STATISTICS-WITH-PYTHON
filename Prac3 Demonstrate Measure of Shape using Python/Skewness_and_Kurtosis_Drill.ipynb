# %% [markdown]
# #### Question
# According to the U.S. Army Corps of Engineers, the top
# 20 U.S. ports, ranked by total tonnage (in million tons),
# were as follows.
# ![image.png](attachment:f150df8b-abf8-413b-a9e7-62034144b2aa.png)

# %% [markdown]
# ###### Discuss the shape of the distribution (skewness and Kurtosis) from the plot.

# %%
import pandas as pd
from scipy.stats import skew, kurtosis
import numpy as np
import pylab as p
import seaborn as sns
import statistics as st
import matplotlib.pyplot as plt

# %%
port = ['Sout Louisiana, LA', 'Houston, TX', 'New York, NY', 'Huntington, WV, KY and OH', 'Long Beach, CA', 'Beaumont, TX', 'Corpus Christi, TX', 'New Orleans, LA', 'Balton Rouge, LA' ,'Texas City, TX',
        'Mobile, AL', 'Los Angeles, CA', 'Lake Charles, LA', 'Tampa, FL', 'Plaquemines, LA', 'Duluth-Superior, MN and WI', 'Valdez, AK', 'Baltimore, MD', 'Pittsburgh, PA', 'Philadephia, PA']
total_tonnage=[212.7,211.7,152.1,83.9,79.9,78.9,77.6,65.9,59.3,57.8,57.7,54.9,52.7,49.2,47.9,44.7,44.4,44.1,43.6,39.4]

df1 = pd.DataFrame(index=port,data=total_tonnage)
#df1=df1.rename(columns={0: "Total Tonnage"})
df1
# Out:
#                                 0
# Sout Louisiana, LA          212.7
# Houston, TX                 211.7
# New York, NY                152.1
# Huntington, WV, KY and OH    83.9
# Long Beach, CA               79.9
# Beaumont, TX                 78.9
# Corpus Christi, TX           77.6
# New Orleans, LA              65.9
# Balton Rouge, LA             59.3
# Texas City, TX               57.8
# Mobile, AL                   57.7
# Los Angeles, CA              54.9
# Lake Charles, LA             52.7
# Tampa, FL                    49.2
# Plaquemines, LA              47.9
# Duluth-Superior, MN and WI   44.7
# Valdez, AK                   44.4
# Baltimore, MD                44.1
# Pittsburgh, PA               43.6
# Philadephia, PA              39.4

# %%
df1[0].skew()
# Out:
# 2.0260219391120806

# %%
df1[0].kurt()
# Out:
# 3.16355892716924

# %% [markdown]
# ## ALL THE BEST!!!!

# %% [markdown]
# Thanks
